# %%
# analysising pregnancy data from national survey of family growth.

# %%
import os
os.chdir('/Users/vivek.vanga/DataScience-Learning/thinkstats/ThinkStats2/code')
# !pwd
import nsfg
df = nsfg.ReadFemPreg()
df
# Out:
# /Users/vivek.vanga/DataScience-Learning/thinkstats/ThinkStats2/code
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN         6
# 1           1         2        NaN        NaN       NaN       NaN         6
# 2           2         1        NaN        NaN       NaN       NaN         5
# 3           2         2        NaN        NaN       NaN       NaN         6
# 4           2         3        NaN        NaN       NaN       NaN         6
# 5           6         1        NaN        NaN       NaN       NaN         6
# 6           6         2        NaN        NaN       NaN       NaN         6
# 7           6         3        NaN        NaN       NaN       NaN         6
# 8           7         1        NaN        NaN       NaN       NaN         5
# 9           7         2        NaN        NaN       NaN       NaN         5
# ...

# %%
import numpy as np
print df.shape
# Out:
# (13593, 244)

# %%
df.columns[1]
# Out:
# u'pregordr'

# %%
pregordr = df['pregordr']
type(pregordr)
# Out:
# pandas.core.series.Series

# %%
print pregordr[0]
print pregordr[2:5]
# Out:
# 1
# 2    1
# 3    2
# 4    3
# Name: pregordr, dtype: int64

# %%
## pandas nan is numpy's nan
type(df['howpreg_n'][0])
# Out:
# numpy.float64

# %%
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN         6
# 1           1         2        NaN        NaN       NaN       NaN         6
# 2           2         1        NaN        NaN       NaN       NaN         5
# 3           2         2        NaN        NaN       NaN       NaN         6
# 4           2         3        NaN        NaN       NaN       NaN         6
# 5           6         1        NaN        NaN       NaN       NaN         6
# 6           6         2        NaN        NaN       NaN       NaN         6
# 7           6         3        NaN        NaN       NaN       NaN         6
# 8           7         1        NaN        NaN       NaN       NaN         5
# 9           7         2        NaN        NaN       NaN       NaN         5
# 10         12         1        NaN        NaN       NaN       NaN         5
# ...

# %%
df['totalwgt_lb']
# Out:
# 0        8.8125
# 1        7.8750
# 2        9.1250
# 3        7.0000
# 4        6.1875
# 5        8.5625
# 6        9.5625
# 7        8.3750
# 8        7.5625
# 9        6.6250
# 10       7.8125
# 11       7.0000
# 12       4.0000
# 13          NaN
# 14          NaN
# 15       7.6875
# 16       7.5000
# 17       6.3125
# 18          NaN
# 19       8.7500
# 20       8.1875
# 21       5.5625
# 22          NaN
# 23       6.7500
# 24       7.3750
# 25       6.8125
# 26       8.1250
# 27       7.1250
# 28       6.0625
# 29       7.4375
#           ...
# 13563    7.6875
# 13564    7.6250
# 13565    8.1250
# 13566    7.5000
# 13567       NaN
# 13568       NaN
# 13569    5.8125
# 13570    6.6875
# 13571    6.0000
# 13572    5.8125
# 13573    6.5625
# 13574    6.1250
# 13575       NaN
# 13576    6.4375
# 13577       NaN
# 13578    6.0000
# 13579    7.0000
# 13580       NaN
# 13581    6.3750
# 13582       NaN
# 13583       NaN
# 13584    6.3750
# 13585       NaN
# 13586       NaN
# ...

# %%
df.outcome.value_counts().sort_index()
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %%
df.birthwgt_lb.value_counts().sort_index()
# Out:
# 0        8
# 1       40
# 2       53
# 3       98
# 4      229
# 5      697
# 6     2223
# 7     3049
# 8     1889
# 9      623
# 10     132
# 11      26
# 12      10
# 13       3
# 14       3
# 15       1
# Name: birthwgt_lb, dtype: int64

# %%
df.caseid
# Out:
# 0            1
# 1            1
# 2            2
# 3            2
# 4            2
# 5            6
# 6            6
# 7            6
# 8            7
# 9            7
# 10          12
# 11          14
# 12          14
# 13          14
# 14          15
# 15          15
# 16          15
# 17          18
# 18          18
# 19          21
# 20          21
# 21          23
# 22          23
# 23          24
# 24          24
# 25          24
# 26          28
# 27          31
# 28          31
# 29          31
#          ...
# 13563    12547
# 13564    12547
# 13565    12550
# 13566    12551
# 13567    12554
# 13568    12554
# 13569    12556
# 13570    12556
# 13571    12556
# 13572    12556
# 13573    12561
# 13574    12561
# 13575    12564
# 13576    12565
# 13577    12565
# 13578    12566
# 13579    12566
# 13580    12568
# 13581    12568
# 13582    12568
# 13583    12569
# 13584    12569
# 13585    12570
# 13586    12570
# 13587    12570
# 13588    12571
# 13589    12571
# ...

# %%
from collections import defaultdict
def MakePregMap(df):
    d = defaultdict(list)
    for index, caseid in df.caseid.iteritems():
        d[caseid].append(index)
    return d

# %%
preg_map = MakePregMap(df)

# %%
caseid = 10229
indices = preg_map[caseid]
print indices
print df.outcome[indices].values
# Out:
# [11093, 11094, 11095, 11096, 11097, 11098, 11099]
# [4 4 4 4 4 4 1]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# matplotlib hello world
plt.xlabel('data_point')
plt.ylabel('frequency')
plt.hist([1,2,2,3,5,2])
# Out:
# (array([ 1.,  0.,  3.,  0.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 10 Patch objects>)

# %%
df.agepreg
# Out:
# 0        33.16
# 1        39.25
# 2        14.33
# 3        17.83
# 4        18.33
# 5        27.00
# 6        28.83
# 7        30.16
# 8        28.08
# 9        32.33
# 10       25.75
# 11       23.00
# 12       24.58
# 13       29.83
# 14       27.50
# 15       28.33
# 16       30.33
# 17       18.91
# 18       27.83
# 19       27.91
# 20       30.58
# 21       18.91
# 22       27.08
# 23       22.25
# 24       25.75
# 25       29.41
# 26       32.66
# 27       18.83
# 28       20.83
# 29       21.66
#          ...
# 13563    21.08
# 13564    23.33
# 13565    20.25
# 13566    32.66
# 13567    16.75
# 13568    23.83
# 13569    18.00
# 13570    24.41
# 13571    27.83
# 13572    33.16
# 13573    22.25
# 13574    24.41
# 13575    18.83
# 13576    31.66
# 13577      NaN
# 13578    24.00
# 13579    25.91
# 13580    28.25
# 13581    30.66
# 13582    33.25
# 13583    23.66
# 13584    26.91
# 13585    21.41
# 13586    22.41
# 13587    23.41
# 13588    17.91
# 13589    18.50
# ...

# %%
import pandas as pd
import numpy as np
# Series.hist :-)
df.birthwgt_oz.hist(bins=30)

# %%
df.agepreg.hist(bins=40)

# %%
df.prglngth.hist(bins=40)

# %%
preg = nsfg.ReadFemPreg()
live = preg[preg.outcome == 1]

# %%
live
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN         6
# 1           1         2        NaN        NaN       NaN       NaN         6
# 2           2         1        NaN        NaN       NaN       NaN         5
# 3           2         2        NaN        NaN       NaN       NaN         6
# 4           2         3        NaN        NaN       NaN       NaN         6
# 5           6         1        NaN        NaN       NaN       NaN         6
# 6           6         2        NaN        NaN       NaN       NaN         6
# 7           6         3        NaN        NaN       NaN       NaN         6
# 8           7         1        NaN        NaN       NaN       NaN         5
# 9           7         2        NaN        NaN       NaN       NaN         5
# 10         12         1        NaN        NaN       NaN       NaN         5
# ...

# %%
live.birthwgt_lb.hist()

# %%
first_baby_data = live[live.birthord == 1]
others = live[live.birthord != 1]
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
first_baby_data.prglngth.hist(bins = 40)
plt.subplot(1,2,2)
others.prglngth.hist(bins = 40)

# %%
mean = live.prglngth.mean()
var = live.prglngth.var()
std = live.prglngth.std()
print "mean: %s" % mean
print "var: %s" %var
print "std: %s" %std
# Out:
# mean: 38.5605596852
# var: 7.30266206783
# std: 2.70234381007
